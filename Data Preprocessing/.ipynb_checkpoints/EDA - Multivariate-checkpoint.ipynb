# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0          flat         dlf the ultima   sector 81   2.20         10476.0
# 1          flat   siddhartha apartment   sector 95   1.10          4327.0
# 2          flat      chintels paradiso  sector 109   1.97          7490.0
# 3          flat        ambience lagoon   sector 24   5.80         12500.0
# 4          flat  shri balaji apartment   sector 12   0.35          4037.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2100.0              Super Built up area 2100(195.1 sq.m.)        3
# 1  2542.0                   Carpet area: 2542 (236.16 sq.m.)        4
# 2  2630.0             Super Built up area 2630(244.33 sq.m.)        4
# 3  4640.0                 Built Up area: 3700 (343.74 sq.m.)        3
# 4   867.0  Super Built up area 867(80.55 sq.m.)Built Up a...        2
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         4      3+      17.0        East  Relatively New
# 1         3       3       9.0       North  Relatively New
# 2         4       2      11.0  North-East  Relatively New
# 3         4      3+       9.0  North-East    Old Property
# 4         2       1       1.0       North  Moderately Old
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               2100.0            NaN          NaN           0             1
# 1                  NaN            NaN       2542.0           0             1
# 2               2630.0            NaN          NaN           0             1
# 3                  NaN         3700.0          NaN           1             1
# 4                867.0          737.0        650.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                2            49
# 1           0           0       1                0            22
# 2           0           1       0                0            49
# 3           0           1       1                2            68
# 4           0           0       0                0            23

# %% [markdown]
# ### property_type vs price

# %%
sns.barplot(x=df['property_type'], y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'], y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# ### property_type vs area

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ### property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 47            flat           ambience caitriona  sector 24  14.00
# 193          house     unitech uniworld resorts  sector 33  10.00
# 233          house                  independent  sector 17   3.50
# 248          house                  independent  sector 55   1.45
# 366          house                  independent  sector 12   3.50
# 448          house                  independent   sector 4   0.60
# 748          house                    rk excelo  sector 12   0.60
# 983          house                  independent  sector 54   3.75
# 1196         house                   ardee city  sector 52   5.50
# 1373         house     unitech uniworld resorts  sector 33   9.50
# 1457         house          huda plot sector 38  sector 38   4.30
# 1639         house                  independent  sector 12   6.00
# 1839         house       dlf city plots phase 2  sector 25  10.00
# 2082         house           vipul tatvam villa  sector 48   7.25
# 2152         house       dlf city plots phase 2  sector 25  10.50
# 2159         house                  independent  sector 57   8.00
# 2277         house       unitech deerwood chase  sector 50   8.45
# 2494         house  unitech nirvana birch court  sector 50   7.10
# 2560         house                        ansal  sector 43   1.85
# 2581         house                  independent  sector 28   4.50
# 2895         house               uppal southend  sector 49   6.75
# 2961         house                  independent  sector 24  10.00
# 3204         house         eros rosewood villas  sector 49   2.75
# 3303         house                  independent  sector 23   2.80
# 3362         house                  independent  sector 38   8.00
# 3386         house            vatika india next  sector 82   7.00
# 3526         house       emaar the palm springs  sector 54  24.00
# 3574         house                dlf the grove  sector 54   5.70
# 3611         house         bhim nagar, sector 6   sector 6   0.85
#
#       price_per_sqft   area  \
# 47          200000.0  700.0
# 193         181818.0  550.0
# 233         218750.0  160.0
# 248         241666.0   60.0
# 366         133079.0  263.0
# 448         105263.0   57.0
# 748         120000.0   50.0
# 983         234375.0  160.0
# 1196        183333.0  300.0
# 1373        173992.0  546.0
# 1457        245398.0  175.0
# 1639        315789.0  190.0
# 1839        400000.0  250.0
# 2082        201388.0  360.0
# 2152        261194.0  402.0
# 2159        266666.0  300.0
# 2277        235376.0  359.0
# 2494        283333.0  251.0
# 2560        308333.0   60.0
# 2581        125000.0  360.0
# 2895        290948.0  232.0
# 2961        229885.0  435.0
# 3204        178571.0  154.0
# 3303        161849.0  173.0
# 3362        230547.0  347.0
# 3386        194444.0  360.0
# 3526        600000.0  400.0
# 3574        211111.0  270.0
# 3611        126865.0   67.0
#
#                                            areaWithType  super_built_up_area  \
# 47                     Built Up area: 700 (65.03 sq.m.)                  NaN
# 193                           Plot area 550(51.1 sq.m.)                  NaN
# 233                    Built Up area: 160 (14.86 sq.m.)                  NaN
# 248                            Plot area 60(5.57 sq.m.)                  NaN
# 366   Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 448                             Plot area 57(5.3 sq.m.)                  NaN
# 748   Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 983                          Plot area 160(14.86 sq.m.)                  NaN
# 1196                         Plot area 300(27.87 sq.m.)                  NaN
# 1373                         Plot area 546(50.73 sq.m.)                  NaN
# 1457  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 1639  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 1839                         Plot area 250(23.23 sq.m.)                  NaN
# 2082                         Plot area 360(33.45 sq.m.)                  NaN
# 2152                         Plot area 402(37.35 sq.m.)                  NaN
# 2159                         Plot area 300(27.87 sq.m.)                  NaN
# 2277                         Plot area 359(33.35 sq.m.)                  NaN
# 2494                          Plot area 240(22.3 sq.m.)                  NaN
# 2560                           Plot area 60(5.57 sq.m.)                  NaN
# 2581                   Built Up area: 360 (33.45 sq.m.)                  NaN
# 2895                         Plot area 232(21.55 sq.m.)                  NaN
# 2961                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 3204  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 3303  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 3362  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 3386  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 3526                         Plot area 400(37.16 sq.m.)                  NaN
# 3574                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 3611                           Plot area 67(6.22 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 47            700.0          NaN
# 193           550.0          NaN
# 233           160.0          NaN
# 248            60.0          NaN
# 366          4800.0       4400.0
# 448            57.0          NaN
# 748            30.0         15.0
# 983           160.0          NaN
# 1196          300.0          NaN
# 1373          546.0          NaN
# 1457          145.0          NaN
# 1639            NaN       1600.0
# 1839          250.0          NaN
# 2082          360.0          NaN
# 2152          402.0          NaN
# 2159          300.0          NaN
# 2277          359.0          NaN
# 2494          240.0          NaN
# 2560           60.0          NaN
# 2581          360.0          NaN
# 2895          232.0          NaN
# 2961            NaN        435.0
# 3204            NaN       1650.0
# 3303          160.0        150.0
# 3362          347.0        215.0
# 3386         3900.0       3743.0
# 3526          400.0          NaN
# 3574          270.0          NaN
# 3611           67.0          NaN

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# checking outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type                    society     sector  price  \
# 64           house                independent  sector 43   4.50
# 165          house                independent  sector 26  26.00
# 242          house                independent  sector 43   7.50
# 244          house                independent  sector 24   4.50
# 450          house                independent  sector 56  11.95
# ...            ...                        ...        ...    ...
# 3423         house                independent  sector 56  12.39
# 3440         house                independent  sector 46   6.81
# 3499         house                independent  sector 57   6.95
# 3732         house                independent  sector 13   2.25
# 3754         house  floor wise designer kothi  sector 25  13.00
#
#       price_per_sqft    area  \
# 64           39062.0  1152.0
# 165          82540.0  3150.0
# 242          38760.0  1935.0
# 244          33333.0  1350.0
# 450          43534.0  2745.0
# ...              ...     ...
# 3423         45889.0  2700.0
# 3440         36911.0  1845.0
# 3499         38611.0  1800.0
# 3732          6944.0  3240.0
# 3754         48148.0  2700.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 64                          Plot area 128(107.02 sq.m.)       20        20
# 165   Plot area 402(336.12 sq.m.)Built Up area: 400 ...       16        16
# 242                         Plot area 215(179.77 sq.m.)       12        12
# 244   Plot area 163(136.29 sq.m.)Built Up area: 160 ...       10         8
# 450                         Plot area 305(255.02 sq.m.)       12        12
# ...                                                 ...      ...       ...
# 3423                        Plot area 300(250.84 sq.m.)       16        18
# 3440                        Plot area 205(171.41 sq.m.)       12        14
# 3499                        Plot area 192(160.54 sq.m.)       12        12
# 3732                    Carpet area: 360 (301.01 sq.m.)       10        10
# 3754                        Plot area 300(250.84 sq.m.)       12        16
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 64        3+       4.0        East  Relatively New                  NaN
# 165       3+       4.0  North-West    New Property                  NaN
# 242       3+       4.0        East    New Property                  NaN
# 244       3+       4.0        East  Relatively New                  NaN
# 450       3+       4.0        West  Relatively New                  NaN
# ...      ...       ...         ...             ...                  ...
# 3423      3+       4.0  North-East    New Property                  NaN
# 3440      3+       NaN        East    New Property                  NaN
# 3499      3+       4.0        East    New Property                  NaN
# 3732       2       1.0        East       Undefined                  NaN
# 3754      3+       4.0  North-East    New Property                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 64           1152.0          NaN           0             1           0
# 165           400.0        350.0           1             1           1
# 242          1935.0          NaN           1             1           1
# 244           160.0        150.0           0             1           1
# 450          2745.0          NaN           0             1           0
# ...             ...          ...         ...           ...         ...
# 3423         2700.0          NaN           0             1           0
# 3440         1845.0          NaN           0             1           0
# 3499         1728.0          NaN           0             1           1
# 3732            NaN        360.0           0             0           0
# 3754         2700.0          NaN           1             1           1
#
#       pooja room  others  furnishing_type  luxury_score
# 64             0       0                2            22
# 165            1       0                1            72
# 242            1       0                1            72
# 244            0       0                1            56
# 450            0       0                1            21
# ...          ...     ...              ...           ...
# 3423           1       0                1            49
# 3440           0       1                1            40
# 3499           0       0                1            73
# 3732           0       0                0             0
# 3754           1       0                1           144
#
# [72 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 304          house      ireo victory valley   sector 67   8.00
# 444          house   vatika the seven lamps   sector 82   1.60
# 786          house         suncity township   sector 54   2.00
# 1105         house              greenopolis   sector 89   0.70
# 1376         house              independent   sector 92   1.80
# 1657         house              spaze privy   sector 72   3.09
# 1898         house          godrej meridien  sector 106   5.60
# 2097         house           dlf the arbour   sector 63   8.50
# 2697         house        suncity avenue 76   sector 76   0.75
# 2925         house              spaze privy   sector 72   3.10
# 3163         house               ninex city   sector 76   1.75
# 3227         house           ats tourmaline  sector 109   1.87
# 3478         house  indiabulls centrum park  sector 103   3.25
# 3638         house      satya the hermitage  sector 103   3.15
#
#       price_per_sqft    area  \
# 304          22222.0  3600.0
# 444           6597.0  2425.0
# 786          30968.0   646.0
# 1105          5397.0  1297.0
# 1376          7627.0  2360.0
# 1657          6981.0  4426.0
# 1898         14000.0  4000.0
# 2097         21519.0  3950.0
# 2697         10067.0   745.0
# 2925          8486.0  3653.0
# 3163          6250.0  2800.0
# 3227          8697.0  2150.0
# 3478          8125.0  4000.0
# 3638          6702.0  4700.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 304                         Plot area 400(334.45 sq.m.)        6         7
# 444                        Plot area 2425(225.29 sq.m.)        4         4
# 786   Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 1105                  Built Up area: 1297 (120.5 sq.m.)        2         2
# 1376                 Built Up area: 2360 (219.25 sq.m.)        4         5
# 1657  Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 1898                       Plot area 4000(371.61 sq.m.)        5         4
# 2097                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 2697  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 2925                       Plot area 3653(339.37 sq.m.)        5         5
# 3163                   Carpet area: 2800 (260.13 sq.m.)        4         4
# 3227                 Built Up area: 2150 (199.74 sq.m.)        3         4
# 3478                       Plot area 4000(371.61 sq.m.)        4         3
# 3638                 Built Up area: 4700 (436.64 sq.m.)        4         5
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 304       3+      51.0  North-East      Moderately Old                  NaN
# 444       3+      16.0       North      Moderately Old                  NaN
# 786        3      11.0       North      Relatively New                  NaN
# 1105       2      14.0  North-East           Undefined                  NaN
# 1376       0      13.0         NaN           Undefined                  NaN
# 1657      3+      14.0        East      Relatively New                  NaN
# 1898      3+      33.0  North-East        New Property                  NaN
# 2097      3+      27.0         NaN           Undefined                  NaN
# 2697       2      11.0  North-East        New Property                  NaN
# 2925      3+      21.0         NaN      Relatively New                  NaN
# 3163       0      14.0         NaN           Undefined                  NaN
# 3227       0      12.0         NaN           Undefined                  NaN
# 3478      3+      20.0         NaN  Under Construction                  NaN
# 3638       0      12.0        East           Undefined                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 304          3600.0          NaN           1             1           0
# 444          2425.0          NaN           0             1           0
# 786            60.0         59.0           0             1           0
# 1105         1297.0          NaN           0             0           0
# 1376         2360.0          NaN           0             0           0
# 1657         3653.0       2922.0           0             1           0
# 1898         4000.0          NaN           1             1           1
# 2097         3950.0          NaN           0             0           0
# 2697          745.0          NaN           0             0           0
# 2925         3653.0          NaN           0             0           0
# 3163            NaN       2800.0           0             0           0
# 3227         2150.0          NaN           0             0           0
# 3478         4000.0          NaN           0             0           0
# 3638         4700.0          NaN           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 304            1       0                1            49
# 444            0       0                0            94
# 786            0       0                2             7
# 1105           0       0                0             0
# 1376           0       0                0             0
# 1657           0       0                1            33
# 1898           1       0                0           151
# 2097           0       0                0            61
# 2697           0       0                0            40
# 2925           0       0                0             0
# 3163           0       0                0             0
# 3227           0       0                0             0
# 3478           0       0                0            51
# 3638           0       0                0            61

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.head()
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0          flat         dlf the ultima   sector 81   2.20         10476.0
# 1          flat   siddhartha apartment   sector 95   1.10          4327.0
# 2          flat      chintels paradiso  sector 109   1.97          7490.0
# 3          flat        ambience lagoon   sector 24   5.80         12500.0
# 4          flat  shri balaji apartment   sector 12   0.35          4037.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2100.0              Super Built up area 2100(195.1 sq.m.)        3
# 1  2542.0                   Carpet area: 2542 (236.16 sq.m.)        4
# 2  2630.0             Super Built up area 2630(244.33 sq.m.)        4
# 3  4640.0                 Built Up area: 3700 (343.74 sq.m.)        3
# 4   867.0  Super Built up area 867(80.55 sq.m.)Built Up a...        2
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         4      3+      17.0        East  Relatively New
# 1         3       3       9.0       North  Relatively New
# 2         4       2      11.0  North-East  Relatively New
# 3         4      3+       9.0  North-East    Old Property
# 4         2       1       1.0       North  Moderately Old
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               2100.0            NaN          NaN           0             1
# 1                  NaN            NaN       2542.0           0             1
# 2               2630.0            NaN          NaN           0             1
# 3                  NaN         3700.0          NaN           1             1
# 4                867.0          737.0        650.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                2            49
# 1           0           0       1                0            22
# 2           0           1       0                0            49
# 3           0           1       1                2            68
# 4           0           0       0                0            23

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
df.head()
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0          flat         dlf the ultima   sector 81   2.20         10476.0
# 1          flat   siddhartha apartment   sector 95   1.10          4327.0
# 2          flat      chintels paradiso  sector 109   1.97          7490.0
# 3          flat        ambience lagoon   sector 24   5.80         12500.0
# 4          flat  shri balaji apartment   sector 12   0.35          4037.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2100.0              Super Built up area 2100(195.1 sq.m.)        3
# 1  2542.0                   Carpet area: 2542 (236.16 sq.m.)        4
# 2  2630.0             Super Built up area 2630(244.33 sq.m.)        4
# 3  4640.0                 Built Up area: 3700 (343.74 sq.m.)        3
# 4   867.0  Super Built up area 867(80.55 sq.m.)Built Up a...        2
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         4      3+      17.0        East  Relatively New
# 1         3       3       9.0       North  Relatively New
# 2         4       2      11.0  North-East  Relatively New
# 3         4      3+       9.0  North-East    Old Property
# 4         2       1       1.0       North  Moderately Old
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               2100.0            NaN          NaN           0             1
# 1                  NaN            NaN       2542.0           0             1
# 2               2630.0            NaN          NaN           0             1
# 3                  NaN         3700.0          NaN           1             1
# 4                867.0          737.0        650.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                2            49
# 1           0           0       1                0            22
# 2           0           1       0                0            49
# 3           0           1       1                2            68
# 4           0           0       0                0            23

# %% [markdown]
# ### price

# %%
filtered_df = df[df['area'] < 10000]
plt.figure(figsize=(12, 8))
sns.scatterplot(x=filtered_df['area'], y=filtered_df['price'], hue=filtered_df['bedRoom'])
plt.show()

# %%
filtered_df = df[df['area'] < 10000]
plt.figure(figsize=(12, 8))
sns.scatterplot(x=filtered_df['area'], y=filtered_df['price'], hue=filtered_df['agePossession'])
plt.show()

# %%
filtered_df = df[df['area'] < 10000]
filtered_df['furnishing_type'] = filtered_df['furnishing_type'].astype('category')
plt.figure(figsize=(12, 8))
sns.scatterplot(x=filtered_df['area'], y=filtered_df['price'], hue=filtered_df['furnishing_type'])
plt.show()
# Out:
# C:\Users\Vedant\AppData\Local\Temp\ipykernel_16240\2407774778.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['furnishing_type'] = filtered_df['furnishing_type'].astype('category')

# %%
sns.barplot(x=df['bedRoom'],y=df['price'])
# Out:
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median)
# Out:
# C:\Python 3.10\lib\site-packages\numpy\lib\nanfunctions.py:1384: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# <Axes: xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(x=df['luxury_score'],y=df['price'])
# Out:
# <Axes: xlabel='luxury_score', ylabel='price'>

# %% [markdown]
# ### correlation

# %%
plt.figure(figsize=(8,8))
df_numeric = df.select_dtypes(include=[np.number])
df_corr = df_numeric.corr()
plt.figure(figsize=(8, 8))
sns.heatmap(df_corr, linewidths=0.5)
plt.show()

# %%
df_numeric = df.select_dtypes(include=[np.number])
corr_price = df_numeric.corr()['price'].sort_values(ascending=False)
print(corr_price)
# Out:
# price                  1.000000
# super_built_up_area    0.769412
# bathroom               0.589826
# built_up_area          0.551649
# bedRoom                0.522925
# servant room           0.400927
# price_per_sqft         0.391251
# pooja room             0.341492
# store room             0.309121
# study room             0.258602
# furnishing_type        0.250160
# luxury_score           0.094775
# area                   0.034720
# others                -0.003525
# carpet_area           -0.011344
# floorNum              -0.094290
# Name: price, dtype: float64

# %%
df.head()
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0          flat         dlf the ultima   sector 81   2.20         10476.0
# 1          flat   siddhartha apartment   sector 95   1.10          4327.0
# 2          flat      chintels paradiso  sector 109   1.97          7490.0
# 3          flat        ambience lagoon   sector 24   5.80         12500.0
# 4          flat  shri balaji apartment   sector 12   0.35          4037.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2100.0              Super Built up area 2100(195.1 sq.m.)        3
# 1  2542.0                   Carpet area: 2542 (236.16 sq.m.)        4
# 2  2630.0             Super Built up area 2630(244.33 sq.m.)        4
# 3  4640.0                 Built Up area: 3700 (343.74 sq.m.)        3
# 4   867.0  Super Built up area 867(80.55 sq.m.)Built Up a...        2
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         4      3+      17.0        East  Relatively New
# 1         3       3       9.0       North  Relatively New
# 2         4       2      11.0  North-East  Relatively New
# 3         4      3+       9.0  North-East    Old Property
# 4         2       1       1.0       North  Moderately Old
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               2100.0            NaN          NaN           0             1
# 1                  NaN            NaN       2542.0           0             1
# 2               2630.0            NaN          NaN           0             1
# 3                  NaN         3700.0          NaN           1             1
# 4                867.0          737.0        650.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                2            49
# 1           0           0       1                0            22
# 2           0           1       0                0            49
# 3           0           1       1                2            68
# 4           0           0       0                0            23

# %%
sns.pairplot(df)
# Out:
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python 3.10\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
